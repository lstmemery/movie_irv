# %%
import pandas as pd
import pyrankvote

# %%
df = pd.read_csv('./data/20200601.csv')
df
# Out:
#              Timestamp  \
# 0   5/27/2020 22:35:03
# 1   5/27/2020 22:40:22
# 2   5/27/2020 22:41:31
# 3    5/28/2020 1:28:01
# 4    5/28/2020 5:41:08
# 5    5/28/2020 6:32:14
# 6    5/28/2020 7:01:34
# 7    5/28/2020 7:42:49
# 8    5/28/2020 8:41:33
# 9    5/28/2020 8:53:02
# 10   5/28/2020 8:53:21
#
#    Rank your movie choices. You don't have to do a full ranking. [First Choice]  \
# 0                                           Your Name
# 1                                The Devil's Backbone
# 2                                     Throne of Blood
# 3                                     Throne of Blood
# 4                                           Your Name
# 5                                     Outside the Law
# 6                                The Devil's Backbone
# 7                                     Outside the Law
# 8                                              Marjoe
# 9                                  The Lion In Winter
# 10                                             Marjoe
#
#    Rank your movie choices. You don't have to do a full ranking. [Second Choice]  \
# 0                                     Throne of Blood
# 1                                              Marjoe
# 2                                  The Lion In Winter
# 3                                           Your Name
# 4                                The Devil's Backbone
# 5                                The Devil's Backbone
# 6                                           Your Name
# 7                                     Throne of Blood
# 8                                       Shallow Grave
# 9                                The Devil's Backbone
# 10                                 The Lion In Winter
#
#    Rank your movie choices. You don't have to do a full ranking. [Third Choice]  \
# 0                                     Outside the Law
# 1                                       Shallow Grave
# 2                                              Marjoe
# 3                                        Seventh Seal
# 4                                                 NaN
# 5                                           Your Name
# 6                                        Seventh Seal
# 7                                              Marjoe
# 8                                         City Lights
# 9                                              Marjoe
# 10                                    Throne of Blood
#
#    Rank your movie choices. You don't have to do a full ranking. [Fourth Choice]  \
# 0                                    The Public Enemy
# 1                                     Throne of Blood
# 2                                    The Public Enemy
# 3                                    The Public Enemy
# 4                                                 NaN
# 5                                              Marjoe
# 6                                     Throne of Blood
# 7                                The Devil's Backbone
# 8                                  The Lion In Winter
# 9                                           Your Name
# 10                                   The Public Enemy
#
#    Rank your movie choices. You don't have to do a full ranking. [Fifth Choice]  \
# 0                                              Marjoe
# 1                                        Seventh Seal
# 2                                The Devil's Backbone
# 3                                       Shallow Grave
# 4                                                 NaN
# 5                                     Throne of Blood
# 6                                                 NaN
# 7                                  The Lion In Winter
# 8                                                 NaN
# 9                                     Throne of Blood
# 10                                          Your Name
#
#    Rank your movie choices. You don't have to do a full ranking. [Sixth Choice]  \
# 0                                The Devil's Backbone
# 1                                    The Public Enemy
# 2                                           Your Name
# 3                                  The Lion In Winter
# 4                                                 NaN
# 5                                  The Lion In Winter
# 6                                                 NaN
# 7                                        Seventh Seal
# 8                                                 NaN
# 9                                     Outside the Law
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Seventh Choice]  \
# 0                                         City Lights
# 1                                     Outside the Law
# 2                                       Shallow Grave
# 3                                     Outside the Law
# 4                                                 NaN
# 5                                    The Public Enemy
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Eighth Choice]  \
# 0                                       Shallow Grave
# 1                                  The Lion In Winter
# 2                                     Outside the Law
# 3                                              Marjoe
# 4                                                 NaN
# 5                                        Seventh Seal
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Nineth Choice]  \
# 0                                        Seventh Seal
# 1                                         City Lights
# 2                                                 NaN
# 3                                The Devil's Backbone
# 4                                                 NaN
# 5                                         City Lights
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Tenth Choice]
# 0                                  The Lion In Winter
# 1                                           Your Name
# 2                                                 NaN
# 3                                         City Lights
# 4                                                 NaN
# 5                                       Shallow Grave
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN

# %%
just_ballots = df.drop(df.columns[0:1], axis=1)
just_ballots
# Out:
#    Rank your movie choices. You don't have to do a full ranking. [First Choice]  \
# 0                                           Your Name
# 1                                The Devil's Backbone
# 2                                     Throne of Blood
# 3                                     Throne of Blood
# 4                                           Your Name
# 5                                     Outside the Law
# 6                                The Devil's Backbone
# 7                                     Outside the Law
# 8                                              Marjoe
# 9                                  The Lion In Winter
# 10                                             Marjoe
#
#    Rank your movie choices. You don't have to do a full ranking. [Second Choice]  \
# 0                                     Throne of Blood
# 1                                              Marjoe
# 2                                  The Lion In Winter
# 3                                           Your Name
# 4                                The Devil's Backbone
# 5                                The Devil's Backbone
# 6                                           Your Name
# 7                                     Throne of Blood
# 8                                       Shallow Grave
# 9                                The Devil's Backbone
# 10                                 The Lion In Winter
#
#    Rank your movie choices. You don't have to do a full ranking. [Third Choice]  \
# 0                                     Outside the Law
# 1                                       Shallow Grave
# 2                                              Marjoe
# 3                                        Seventh Seal
# 4                                                 NaN
# 5                                           Your Name
# 6                                        Seventh Seal
# 7                                              Marjoe
# 8                                         City Lights
# 9                                              Marjoe
# 10                                    Throne of Blood
#
#    Rank your movie choices. You don't have to do a full ranking. [Fourth Choice]  \
# 0                                    The Public Enemy
# 1                                     Throne of Blood
# 2                                    The Public Enemy
# 3                                    The Public Enemy
# 4                                                 NaN
# 5                                              Marjoe
# 6                                     Throne of Blood
# 7                                The Devil's Backbone
# 8                                  The Lion In Winter
# 9                                           Your Name
# 10                                   The Public Enemy
#
#    Rank your movie choices. You don't have to do a full ranking. [Fifth Choice]  \
# 0                                              Marjoe
# 1                                        Seventh Seal
# 2                                The Devil's Backbone
# 3                                       Shallow Grave
# 4                                                 NaN
# 5                                     Throne of Blood
# 6                                                 NaN
# 7                                  The Lion In Winter
# 8                                                 NaN
# 9                                     Throne of Blood
# 10                                          Your Name
#
#    Rank your movie choices. You don't have to do a full ranking. [Sixth Choice]  \
# 0                                The Devil's Backbone
# 1                                    The Public Enemy
# 2                                           Your Name
# 3                                  The Lion In Winter
# 4                                                 NaN
# 5                                  The Lion In Winter
# 6                                                 NaN
# 7                                        Seventh Seal
# 8                                                 NaN
# 9                                     Outside the Law
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Seventh Choice]  \
# 0                                         City Lights
# 1                                     Outside the Law
# 2                                       Shallow Grave
# 3                                     Outside the Law
# 4                                                 NaN
# 5                                    The Public Enemy
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Eighth Choice]  \
# 0                                       Shallow Grave
# 1                                  The Lion In Winter
# 2                                     Outside the Law
# 3                                              Marjoe
# 4                                                 NaN
# 5                                        Seventh Seal
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Nineth Choice]  \
# 0                                        Seventh Seal
# 1                                         City Lights
# 2                                                 NaN
# 3                                The Devil's Backbone
# 4                                                 NaN
# 5                                         City Lights
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Rank your movie choices. You don't have to do a full ranking. [Tenth Choice]
# 0                                  The Lion In Winter
# 1                                           Your Name
# 2                                                 NaN
# 3                                         City Lights
# 4                                                 NaN
# 5                                       Shallow Grave
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN

# %%
submissions = just_ballots.loc[just_ballots.notna().all(axis=1).idxmax(),:].values
submissions
# Out:
# array(['Your Name', 'Throne of Blood', 'Outside the Law',
#        'The Public Enemy', 'Marjoe', "The Devil's Backbone",
#        'City Lights', 'Shallow Grave', 'Seventh Seal',
#        'The Lion In Winter'], dtype=object)

# %%
submission_dict = {submission: pyrankvote.Candidate(submission) for submission in submissions}

# %%
balloted = just_ballots.applymap(lambda x: submission_dict[x] if isinstance(x, str) else x)

# %%
submission_dict
# Out:
# {'Your Name': <Candidate('Your Name')>,
#  'Throne of Blood': <Candidate('Throne of Blood')>,
#  'Outside the Law': <Candidate('Outside the Law')>,
#  'The Public Enemy': <Candidate('The Public Enemy')>,
#  'Marjoe': <Candidate('Marjoe')>,
#  "The Devil's Backbone": <Candidate('The Devil's Backbone')>,
#  'City Lights': <Candidate('City Lights')>,
#  'Shallow Grave': <Candidate('Shallow Grave')>,
#  'Seventh Seal': <Candidate('Seventh Seal')>,
#  'The Lion In Winter': <Candidate('The Lion In Winter')>}

# %%
ballots = []
for ballot in balloted.itertuples():
    ballots.append(pyrankvote.Ballot(ranked_candidates=[b for b in ballot if isinstance(b, pyrankvote.Candidate)]))

# %%
ballots
# Out:
# [<Ballot(Your Name, Throne of Blood, Outside the Law, The Public Enemy, Marjoe, The Devil's Backbone, City Lights, Shallow Grave, Seventh Seal, The Lion In Winter)>,
#  <Ballot(The Devil's Backbone, Marjoe, Shallow Grave, Throne of Blood, Seventh Seal, The Public Enemy, Outside the Law, The Lion In Winter, City Lights, Your Name)>,
#  <Ballot(Throne of Blood, The Lion In Winter, Marjoe, The Public Enemy, The Devil's Backbone, Your Name, Shallow Grave, Outside the Law)>,
#  <Ballot(Throne of Blood, Your Name, Seventh Seal, The Public Enemy, Shallow Grave, The Lion In Winter, Outside the Law, Marjoe, The Devil's Backbone, City Lights)>,
#  <Ballot(Your Name, The Devil's Backbone)>,
#  <Ballot(Outside the Law, The Devil's Backbone, Your Name, Marjoe, Throne of Blood, The Lion In Winter, The Public Enemy, Seventh Seal, City Lights, Shallow Grave)>,
#  <Ballot(The Devil's Backbone, Your Name, Seventh Seal, Throne of Blood)>,
#  <Ballot(Outside the Law, Throne of Blood, Marjoe, The Devil's Backbone, The Lion In Winter, Seventh Seal)>,
#  <Ballot(Marjoe, Shallow Grave, City Lights, The Lion In Winter)>,
#  <Ballot(The Lion In Winter, The Devil's Backbone, Marjoe, Your Name, Throne of Blood, Outside the Law)>,
#  <Ballot(Marjoe, The Lion In Winter, Throne of Blood, The Public Enemy, Your Name)>]

# %%
election_result = pyrankvote.instant_runoff_voting(submission_dict.values(), ballots,)

# %%
print(election_result)
# Out:
# ROUND 1
# Candidate               Votes  Status
# --------------------  -------  --------
# The Devil's Backbone        2  Hopeful
# Throne of Blood             2  Hopeful
# Your Name                   2  Hopeful
# Marjoe                      2  Hopeful
# Outside the Law             2  Hopeful
# The Lion In Winter          1  Rejected
# Shallow Grave               0  Rejected
# Seventh Seal                0  Rejected
# City Lights                 0  Rejected
# The Public Enemy            0  Rejected
#
# ROUND 2
# Candidate               Votes  Status
# --------------------  -------  --------
# The Devil's Backbone        3  Hopeful
# Throne of Blood             2  Hopeful
# Marjoe                      2  Hopeful
# Your Name                   2  Hopeful
# Outside the Law             2  Rejected
# The Lion In Winter          0  Rejected
# Shallow Grave               0  Rejected
# Seventh Seal                0  Rejected
# City Lights                 0  Rejected
# The Public Enemy            0  Rejected
#
# ROUND 3
# Candidate               Votes  Status
# --------------------  -------  --------
# The Devil's Backbone        4  Hopeful
# Throne of Blood             3  Hopeful
# Marjoe                      2  Hopeful
# Your Name                   2  Rejected
# Outside the Law             0  Rejected
# The Lion In Winter          0  Rejected
# Shallow Grave               0  Rejected
# Seventh Seal                0  Rejected
# City Lights                 0  Rejected
# The Public Enemy            0  Rejected
#
# ROUND 4
# Candidate               Votes  Status
# --------------------  -------  --------
# The Devil's Backbone        5  Hopeful
# Throne of Blood             4  Hopeful
# Marjoe                      2  Rejected
# Your Name                   0  Rejected
# Outside the Law             0  Rejected
# The Lion In Winter          0  Rejected
# Shallow Grave               0  Rejected
# Seventh Seal                0  Rejected
# City Lights                 0  Rejected
# The Public Enemy            0  Rejected
#
# FINAL RESULT
# Candidate               Votes  Status
# --------------------  -------  --------
# Throne of Blood             5  Elected
# The Devil's Backbone        5  Rejected
# Marjoe                      0  Rejected
# Your Name                   0  Rejected
# Outside the Law             0  Rejected
# The Lion In Winter          0  Rejected
# Shallow Grave               0  Rejected
# Seventh Seal                0  Rejected
# City Lights                 0  Rejected
# The Public Enemy            0  Rejected
# Blank votes                 1  Rejected
