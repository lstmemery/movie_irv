# %%
import pandas as pd
import pyrankvote

# %%
df = pd.read_csv('./data/20200518.csv')
df
# Out:
#             Timestamp  \
# 0  5/17/2020 12:21:20
# 1  5/17/2020 12:53:26
# 2  5/17/2020 13:15:32
# 3  5/17/2020 13:32:35
# 4  5/17/2020 13:35:55
# 5  5/17/2020 13:39:44
# 6  5/17/2020 14:45:50
# 7  5/17/2020 17:31:44
#
#   Rank your movie choices. You don't have to do a full ranking. [First Choice]  \
# 0                                       Dead Ringers
# 1                                 Antonio das Mortes
# 2                                       O Lucky Man!
# 3                                             Freaks
# 4                                 Antonio das Mortes
# 5                                 Antonio das Mortes
# 6                                 Antonio das Mortes
# 7                                       O Lucky Man!
#
#   Rank your movie choices. You don't have to do a full ranking. [Second Choice]  \
# 0                                Hiroshima mon Amour
# 1                                             Freaks
# 2                                 Antonio das Mortes
# 3                                       O Lucky Man!
# 4                             Umbrellas of Cherbourg
# 5                             Umbrellas of Cherbourg
# 6                                       Seventh Seal
# 7                                       Dead Ringers
#
#   Rank your movie choices. You don't have to do a full ranking. [Third Choice]  \
# 0                                       O Lucky Man!
# 1                                       O Lucky Man!
# 2                                       Dead Ringers
# 3                                 Antonio das Mortes
# 4                                       Seventh Seal
# 5                                             Freaks
# 6                                                NaN
# 7                                 Antonio das Mortes
#
#   Rank your movie choices. You don't have to do a full ranking. [Fourth Choice]  \
# 0                                 Antonio das Mortes
# 1                                       Seventh Seal
# 2                                       Seventh Seal
# 3                                       Dead Ringers
# 4                                       Dead Ringers
# 5                                       Dead Ringers
# 6                                                NaN
# 7                                             Freaks
#
#   Rank your movie choices. You don't have to do a full ranking. [Fifth Choice]  \
# 0                                                NaN
# 1                                Hiroshima mon Amour
# 2                             Umbrellas of Cherbourg
# 3                                       Seventh Seal
# 4                                       O Lucky Man!
# 5                                                NaN
# 6                                                NaN
# 7                                       Seventh Seal
#
#   Rank your movie choices. You don't have to do a full ranking. [Sixth Choice]  \
# 0                                                NaN
# 1                                       Dead Ringers
# 2                                             Freaks
# 3                                Hiroshima mon Amour
# 4                                             Freaks
# 5                                                NaN
# 6                                                NaN
# 7                                Hiroshima mon Amour
#
#   Rank your movie choices. You don't have to do a full ranking. [Seventh Choice]
# 0                                                NaN
# 1                             Umbrellas of Cherbourg
# 2                                Hiroshima mon Amour
# 3                             Umbrellas of Cherbourg
# 4                                Hiroshima mon Amour
# 5                                                NaN
# 6                                                NaN
# 7                             Umbrellas of Cherbourg

# %%
just_ballots = df.drop(df.columns[0:1], axis=1)
just_ballots
# Out:
#   Rank your movie choices. You don't have to do a full ranking. [First Choice]  \
# 0                                       Dead Ringers
# 1                                 Antonio das Mortes
# 2                                       O Lucky Man!
# 3                                             Freaks
# 4                                 Antonio das Mortes
# 5                                 Antonio das Mortes
# 6                                 Antonio das Mortes
# 7                                       O Lucky Man!
#
#   Rank your movie choices. You don't have to do a full ranking. [Second Choice]  \
# 0                                Hiroshima mon Amour
# 1                                             Freaks
# 2                                 Antonio das Mortes
# 3                                       O Lucky Man!
# 4                             Umbrellas of Cherbourg
# 5                             Umbrellas of Cherbourg
# 6                                       Seventh Seal
# 7                                       Dead Ringers
#
#   Rank your movie choices. You don't have to do a full ranking. [Third Choice]  \
# 0                                       O Lucky Man!
# 1                                       O Lucky Man!
# 2                                       Dead Ringers
# 3                                 Antonio das Mortes
# 4                                       Seventh Seal
# 5                                             Freaks
# 6                                                NaN
# 7                                 Antonio das Mortes
#
#   Rank your movie choices. You don't have to do a full ranking. [Fourth Choice]  \
# 0                                 Antonio das Mortes
# 1                                       Seventh Seal
# 2                                       Seventh Seal
# 3                                       Dead Ringers
# 4                                       Dead Ringers
# 5                                       Dead Ringers
# 6                                                NaN
# 7                                             Freaks
#
#   Rank your movie choices. You don't have to do a full ranking. [Fifth Choice]  \
# 0                                                NaN
# 1                                Hiroshima mon Amour
# 2                             Umbrellas of Cherbourg
# 3                                       Seventh Seal
# 4                                       O Lucky Man!
# 5                                                NaN
# 6                                                NaN
# 7                                       Seventh Seal
#
#   Rank your movie choices. You don't have to do a full ranking. [Sixth Choice]  \
# 0                                                NaN
# 1                                       Dead Ringers
# 2                                             Freaks
# 3                                Hiroshima mon Amour
# 4                                             Freaks
# 5                                                NaN
# 6                                                NaN
# 7                                Hiroshima mon Amour
#
#   Rank your movie choices. You don't have to do a full ranking. [Seventh Choice]
# 0                                                NaN
# 1                             Umbrellas of Cherbourg
# 2                                Hiroshima mon Amour
# 3                             Umbrellas of Cherbourg
# 4                                Hiroshima mon Amour
# 5                                                NaN
# 6                                                NaN
# 7                             Umbrellas of Cherbourg

# %%
submissions = just_ballots.iloc[2,:].values
submissions
# Out:
# array(['O Lucky Man!', 'Antonio das Mortes', 'Dead Ringers',
#        'Seventh Seal', 'Umbrellas of Cherbourg', 'Freaks',
#        'Hiroshima mon Amour'], dtype=object)

# %%
submission_dict = {submission: pyrankvote.Candidate(submission) for submission in submissions}

# %%
balloted = just_ballots.applymap(lambda x: submission_dict[x] if isinstance(x, str) else x)

# %%
submission_dict
# Out:
# {'O Lucky Man!': <Candidate('O Lucky Man!')>,
#  'Antonio das Mortes': <Candidate('Antonio das Mortes')>,
#  'Dead Ringers': <Candidate('Dead Ringers')>,
#  'Seventh Seal': <Candidate('Seventh Seal')>,
#  'Umbrellas of Cherbourg': <Candidate('Umbrellas of Cherbourg')>,
#  'Freaks': <Candidate('Freaks')>,
#  'Hiroshima mon Amour': <Candidate('Hiroshima mon Amour')>}

# %%
ballots = []
for ballot in balloted.itertuples():
    ballots.append(pyrankvote.Ballot(ranked_candidates=[b for b in ballot if isinstance(b, pyrankvote.Candidate)]))

# %%
ballots
# Out:
# [<Ballot(Dead Ringers, Hiroshima mon Amour, O Lucky Man!, Antonio das Mortes)>,
#  <Ballot(Antonio das Mortes, Freaks, O Lucky Man!, Seventh Seal, Hiroshima mon Amour, Dead Ringers, Umbrellas of Cherbourg)>,
#  <Ballot(O Lucky Man!, Antonio das Mortes, Dead Ringers, Seventh Seal, Umbrellas of Cherbourg, Freaks, Hiroshima mon Amour)>,
#  <Ballot(Freaks, O Lucky Man!, Antonio das Mortes, Dead Ringers, Seventh Seal, Hiroshima mon Amour, Umbrellas of Cherbourg)>,
#  <Ballot(Antonio das Mortes, Umbrellas of Cherbourg, Seventh Seal, Dead Ringers, O Lucky Man!, Freaks, Hiroshima mon Amour)>,
#  <Ballot(Antonio das Mortes, Umbrellas of Cherbourg, Freaks, Dead Ringers)>,
#  <Ballot(Antonio das Mortes, Seventh Seal)>,
#  <Ballot(O Lucky Man!, Dead Ringers, Antonio das Mortes, Freaks, Seventh Seal, Hiroshima mon Amour, Umbrellas of Cherbourg)>]

# %%
election_result = pyrankvote.instant_runoff_voting(submission_dict.values(), ballots,)

# %%
??pyrankvote.instant_runoff_voting

# %%
print(election_result)
# Out:
# FINAL RESULT
# Candidate                 Votes  Status
# ----------------------  -------  --------
# Antonio das Mortes            4  Elected
# O Lucky Man!                  2  Rejected
# Dead Ringers                  1  Rejected
# Freaks                        1  Rejected
# Umbrellas of Cherbourg        0  Rejected
# Seventh Seal                  0  Rejected
# Hiroshima mon Amour           0  Rejected
